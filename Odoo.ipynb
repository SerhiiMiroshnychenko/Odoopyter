# %% [markdown]
# # Odoopyter
# *Odoo ORM Playground (Jupyter)*

# %%
# %run .\odoo_init.py
# Out:
# 2025-12-15 17:13:57,652 27472 INFO ? odoo.modules.loading: loading 1 modules...
# 2025-12-15 17:13:58,194 27472 INFO ? odoo.modules.loading: 1 modules loaded in 0.54s, 0 queries (+0 extra)
# 2025-12-15 17:13:58,210 27472 INFO ? odoo.modules.loading: loading 20 modules...
# 2025-12-15 17:13:58,706 27472 INFO ? odoo.modules.loading: 20 modules loaded in 0.50s, 0 queries (+0 extra)
# 2025-12-15 17:13:58,739 27472 INFO ? odoo.modules.loading: Modules loaded.
# 2025-12-15 17:13:58,773 27472 INFO ? odoo.registry: Registry loaded in 1.261s
# 2025-12-15 17:13:58,774 27472 INFO ? __main__: Odoo environment is ready.
# 2025-12-15 17:13:58,775 27472 INFO ? __main__:   Database: odoo_db

# %%
print("User:", env_user.name, "| Company:", env_user.company_id.name)
partners = env["res.partner"].search([], limit=5, order="id desc")
print("Partners:", partners.mapped("display_name"))
print("Installed modules:", env["ir.module.module"].search_count([("state", "=", "installed")]))
# Out:
# User: System | Company: My Company
# Partners: ['Administrator', 'My Company']
# Installed modules: 20
