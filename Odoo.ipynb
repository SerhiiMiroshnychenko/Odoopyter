# %% [markdown]
# # Odoopyter
# *Odoo ORM Playground (Jupyter)*

# %%
# %run D:\CUSTOMs\MY\Odoopyter\odoo_init.py
# Out:
# 2025-12-15 16:08:15,943 3736 INFO ? odoo.modules.loading: loading 1 modules...
# 2025-12-15 16:08:17,320 3736 INFO ? odoo.modules.loading: 1 modules loaded in 1.38s, 0 queries (+0 extra)
# 2025-12-15 16:08:17,349 3736 INFO ? odoo.modules.loading: loading 20 modules...
# 2025-12-15 16:08:19,032 3736 INFO ? odoo.modules.loading: 20 modules loaded in 1.68s, 0 queries (+0 extra)
# 2025-12-15 16:08:19,077 3736 INFO ? odoo.modules.loading: Modules loaded.
# 2025-12-15 16:08:19,119 3736 INFO ? odoo.registry: Registry loaded in 3.296s
# 2025-12-15 16:08:19,121 3736 INFO ? __main__: Odoo environment is ready.
# 2025-12-15 16:08:19,121 3736 INFO ? __main__:   Database: odoo_db

# %%
print("User:", env_user.name, "| Company:", env_user.company_id.name)
partners = env["res.partner"].search([], limit=5, order="id desc")
print("Partners:", partners.mapped("display_name"))
print("Installed modules:", env["ir.module.module"].search_count([("state", "=", "installed")]))
# Out:
# User: System | Company: My Company
# Partners: ['Administrator', 'My Company']
# Installed modules: 20
